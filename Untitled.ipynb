# %%
from IPython import display
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as wg

# %matplotlib nbagg

# %%
gslider = wg.IntSlider(
    value=7,
    min=1,
    max=100,
    step=1,
    description='Test:')

# %%
# Out:
# <img src="data:image/png;base64,..." width="600">
# interactive(children=(IntSlider(value=1, description='Test:', min=1), Output()), _dom_classes=('widget-interac…
# <function __main__.graph(g)>
